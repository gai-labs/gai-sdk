# %% [markdown]
# ## Gai Dialogue System
#
# This system is responsible for managing and storing the dialogue messages between the user and the agents. It also handles the context and history of the conversation. It has a dependency on `Gai Messages System`.

# %% [markdown]
# ---
#
# ## 1. Dialogue Bus
#
# ### a) Setup

# %%
from gai.dialogue import DialogueBus
from gai.dialogue.nodes import AsyncAgentNode, AsyncUserNode
from rich import print as rprint

class MockAgentNode(AsyncAgentNode):
    
    def __init__(self, name: str):
        super().__init__(name=name, handle_send_cb=self.handle_send_cb)
        
    async def handle_send_cb(self, message):
        
        # Simulate a response from the agent
        
        if self.name == "Sara":
            message = "This is a story about a brave knight who fought a dragon.".split()
            for word in message:
                yield word+" "
        if self.name == "Diana":
            message = "The knight was very brave and fought valiantly.".split()
            for word in message:
                yield word+" "

# 1. Initiate a dialogue session

dialogue = DialogueBus()
await dialogue.start()

# 2. Add 2 Agents to the Dialogue
    
sara = MockAgentNode(name="Sara")
diana = MockAgentNode(name="Diana")
await sara.subscribe(dialogue=dialogue)
await diana.subscribe(dialogue=dialogue)

# 3. Add 1 User to the Dialogue

async def handle_reply_cb(message):
    rprint(f"[bold green]{message.header.sender} replied:[/bold green] {message.body.chunk}")
    
user = AsyncUserNode(handle_reply_cb=handle_reply_cb)
await user.subscribe(dialogue=dialogue)

# %% [markdown]
# ### b) Send and Reply

# %%
# 3. Ask Sara to tell a story

await user.chat("Tell me a one paragraph story","Sara") 
rprint("[User] [bold bright_yellow] Sent message to Sara [/bold bright_yellow]")

# 4. Ask Diana to continue   

await user.chat("Please continue","Diana")
rprint("[User] [bold bright_yellow] Sent message to Diana [/bold bright_yellow]")
# Out:
# [User]  Sent message to Sara
# [User]  Sent message to Diana
# [Sara] Handle send message. message=id='6687d35c-d848-4c72-890e-3aa10bd2bff8'
# header=MessageHeaderPydantic(sender='User', recipient='Sara', timestamp=1752123048.7185931, order=0)
# body=SendBodyPydantic(type='send', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=1,
# message_id='00000000-0000-0000-0000-000000000000.1', content_type='text', content='Tell me a one paragraph story')
# [Diana] Message not for me, ignore. message=id='6687d35c-d848-4c72-890e-3aa10bd2bff8'
# header=MessageHeaderPydantic(sender='User', recipient='Sara', timestamp=1752123048.7185931, order=0)
# body=SendBodyPydantic(type='send', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=1,
# message_id='00000000-0000-0000-0000-000000000000.1', content_type='text', content='Tell me a one paragraph story')
# [Sara] Message not for me, ignore. message=id='09e9dfd1-087f-44ea-b3b6-62c92cbe506c'
# header=MessageHeaderPydantic(sender='User', recipient='Diana', timestamp=1752123048.727844, order=0)
# body=SendBodyPydantic(type='send', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=2,
# message_id='00000000-0000-0000-0000-000000000000.2', content_type='text', content='Please continue')
# [Diana] Handle send message. message=id='09e9dfd1-087f-44ea-b3b6-62c92cbe506c'
# header=MessageHeaderPydantic(sender='User', recipient='Diana', timestamp=1752123048.727844, order=0)
# body=SendBodyPydantic(type='send', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=2,
# message_id='00000000-0000-0000-0000-000000000000.2', content_type='text', content='Please continue')
# Sara replied: This
# Sara replied: is
# Sara replied: a
# Sara replied: story
# Sara replied: about
# Sara replied: a
# Sara replied: brave
# Sara replied: knight
# Sara replied: who
# Sara replied: fought
# Sara replied: a
# Sara replied: dragon.
# Sara replied: <eom>
# Diana replied: The
# Diana replied: knight
# Diana replied: was
# Diana replied: very
# Diana replied: brave
# Diana replied: and
# Diana replied: fought
# Diana replied: valiantly.
# Diana replied: <eom>

# %% [markdown]
# ### c) Send broadcast messages

# %%
# 1. Send a broadcast message to all agents

await user.chat("Introduce yourselves","*") 
print("[User] [bold bright_yellow] Sent broadcast message [/bold bright_yellow]")
# Out:
# [User] [bold bright_yellow] Sent broadcast message [/bold bright_yellow]
# [Sara] Handle broadcast message. message=id='2549f4b7-91d8-4421-ad86-75c4ad2b3b47'
# header=MessageHeaderPydantic(sender='User', recipient='*', timestamp=1752123052.2796378, order=0)
# body=SendBodyPydantic(type='send', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=25,
# message_id='00000000-0000-0000-0000-000000000000.25', content_type='text', content='Introduce yourselves')
# [Diana] Handle broadcast message. message=id='2549f4b7-91d8-4421-ad86-75c4ad2b3b47'
# header=MessageHeaderPydantic(sender='User', recipient='*', timestamp=1752123052.2796378, order=0)
# body=SendBodyPydantic(type='send', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=25,
# message_id='00000000-0000-0000-0000-000000000000.25', content_type='text', content='Introduce yourselves')
# Sara replied: This
# Sara replied: is
# Sara replied: a
# Sara replied: story
# Sara replied: about
# Sara replied: a
# Sara replied: brave
# Sara replied: knight
# Sara replied: who
# Sara replied: fought
# Sara replied: a
# Sara replied: dragon.
# Sara replied: <eom>
# Diana replied: The
# Diana replied: knight
# Diana replied: was
# Diana replied: very
# Diana replied: brave
# Diana replied: and
# Diana replied: fought
# Diana replied: valiantly.
# Diana replied: <eom>

# %%
print(dialogue.list_messages())
# Out:
# [MessagePydantic(id='6687d35c-d848-4c72-890e-3aa10bd2bff8', header=MessageHeaderPydantic(sender='User', recipient='Sara', timestamp=1752123048.7185931, order=0), body=SendBodyPydantic(type='send', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=1, message_id='00000000-0000-0000-0000-000000000000.1', content_type='text', content='Tell me a one paragraph story')), MessagePydantic(id='09e9dfd1-087f-44ea-b3b6-62c92cbe506c', header=MessageHeaderPydantic(sender='User', recipient='Diana', timestamp=1752123048.727844, order=0), body=SendBodyPydantic(type='send', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=2, message_id='00000000-0000-0000-0000-000000000000.2', content_type='text', content='Please continue')), MessagePydantic(id='a4b5f89b-cb95-43ec-bd55-72cfa7dcb9af', header=MessageHeaderPydantic(sender='Sara', recipient='User', timestamp=1752123048.7394762, order=0), body=ReplyBodyPydantic(type='reply', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=15, message_id='00000000-0000-0000-0000-000000000000.15', chunk_no=12, chunk='<eom>', content_type='text', content='This is a story about a brave knight who fought a dragon. ')), MessagePydantic(id='82d07edc-ea2a-4484-aa99-ac49460a2f25', header=MessageHeaderPydantic(sender='Diana', recipient='User', timestamp=1752123048.7540681, order=0), body=ReplyBodyPydantic(type='reply', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=24, message_id='00000000-0000-0000-0000-000000000000.24', chunk_no=8, chunk='<eom>', content_type='text', content='The knight was very brave and fought valiantly. ')), MessagePydantic(id='2549f4b7-91d8-4421-ad86-75c4ad2b3b47', header=MessageHeaderPydantic(sender='User', recipient='*', timestamp=1752123052.2796378, order=0), body=SendBodyPydantic(type='send', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=25, message_id='00000000-0000-0000-0000-000000000000.25', content_type='text', content='Introduce yourselves')), MessagePydantic(id='0c55875f-7227-44da-8f57-828f070c705a', header=MessageHeaderPydantic(sender='Sara', recipient='User', timestamp=1752123052.2901049, order=0), body=ReplyBodyPydantic(type='reply', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=38, message_id='00000000-0000-0000-0000-000000000000.38', chunk_no=12, chunk='<eom>', content_type='text', content='This is a story about a brave knight who fought a dragon. ')), MessagePydantic(id='adf37085-edc8-4d25-aec4-c4eefdaab972', header=MessageHeaderPydantic(sender='Diana', recipient='User', timestamp=1752123052.2946887, order=0), body=ReplyBodyPydantic(type='reply', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=47, message_id='00000000-0000-0000-0000-000000000000.47', chunk_no=8, chunk='<eom>', content_type='text', content='The knight was very brave and fought valiantly. '))]

# %% [markdown]
# ---
#
# ## 4. File Dialogue Bus

# %%
import asyncio
from gai.messages import message_helper
from gai.dialogue import FileDialogueBus, DialogueBus
from rich import print

from gai.dialogue.nodes import AsyncAgentNode, AsyncUserNode

class MockFileAgentNode(MockAgentNode):
    
    def __init__(self, name: str):
        super().__init__(name=name)
        
    def _stream_completion(self, message):
        
        # Simulate a response from the agent
        
        if self.name == "Sara":
            yield "This is a story about a brave knight who fought a dragon."
        if self.name == "Diana":
            yield "The knight was very brave and fought valiantly."

# 1. Initiate a dialogue session
from gai.lib.tests import make_local_tmp
here = make_local_tmp()
dialogue_id = FileDialogueBus.create_dialogue_id()

# 2. Add 1 User and 2 Agents to the Dialogue

dialogue = FileDialogueBus(
    logger_name="User", 
    app_dir=here,
    dialogue_id=dialogue_id,
    reset=True
    )
await dialogue.start()
    
sara = MockAgentNode(name="Sara")
await sara.subscribe(dialogue=dialogue)
diana = MockAgentNode(name="Diana")
await diana.subscribe(dialogue=dialogue)
user = AsyncUserNode()
await user.subscribe(dialogue=dialogue)

# %% [markdown]
# ### b) Send and Reply

# %%
# 3. Ask Sara to tell a story

await user.chat("Tell me a one paragraph story","Sara") 
print("[User] [bold bright_yellow] Sent message to Sara [/bold bright_yellow]")

# # 4. Ask Diana to continue   

await user.chat("Please continue","Diana")
print("[User] [bold bright_yellow] Sent message to Diana [/bold bright_yellow]")
# Out:
# [User]  Sent message to Sara
# [User]  Sent message to Diana
# [Sara] Handle send message. message=id='fc46f385-05cf-4dd5-bd27-25ed18f627d1'
# header=MessageHeaderPydantic(sender='User', recipient='Sara', timestamp=1752123060.2611365, order=0)
# body=SendBodyPydantic(type='send', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=48,
# message_id='00000000-0000-0000-0000-000000000000.48', content_type='text', content='Tell me a one paragraph story')
# [Diana] Message not for me, ignore. message=id='fc46f385-05cf-4dd5-bd27-25ed18f627d1'
# header=MessageHeaderPydantic(sender='User', recipient='Sara', timestamp=1752123060.2611365, order=0)
# body=SendBodyPydantic(type='send', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=48,
# message_id='00000000-0000-0000-0000-000000000000.48', content_type='text', content='Tell me a one paragraph story')
# [Sara] Message not for me, ignore. message=id='8cc86f83-f6a8-4edb-92b4-4d7d0aa68802'
# header=MessageHeaderPydantic(sender='User', recipient='Diana', timestamp=1752123060.2651765, order=0)
# body=SendBodyPydantic(type='send', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=49,
# message_id='00000000-0000-0000-0000-000000000000.49', content_type='text', content='Please continue')
# [Diana] Handle send message. message=id='8cc86f83-f6a8-4edb-92b4-4d7d0aa68802'
# header=MessageHeaderPydantic(sender='User', recipient='Diana', timestamp=1752123060.2651765, order=0)
# body=SendBodyPydantic(type='send', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=49,
# message_id='00000000-0000-0000-0000-000000000000.49', content_type='text', content='Please continue')

# %% [markdown]
# ### c) Send broadcast messages

# %%
# 1. Send a broadcast message to all agents

await user.chat("Introduce yourselves","*") 
print("[User] [bold bright_yellow] Sent broadcast message [/bold bright_yellow]")
# Out:
# [User]  Sent broadcast message
# [Sara] Handle broadcast message. message=id='4d9c8020-186c-43dc-9d14-938a31f5e7dd'
# header=MessageHeaderPydantic(sender='User', recipient='*', timestamp=1752123063.2592404, order=0)
# body=SendBodyPydantic(type='send', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=78,
# message_id='00000000-0000-0000-0000-000000000000.78', content_type='text', content='Introduce yourselves')
# [Diana] Handle broadcast message. message=id='4d9c8020-186c-43dc-9d14-938a31f5e7dd'
# header=MessageHeaderPydantic(sender='User', recipient='*', timestamp=1752123063.2592404, order=0)
# body=SendBodyPydantic(type='send', dialogue_id='00000000-0000-0000-0000-000000000000', message_no=78,
# message_id='00000000-0000-0000-0000-000000000000.78', content_type='text', content='Introduce yourselves')

# %% [markdown]
# ### d) Check File

# %%
from gai.lib.constants import DEFAULT_GUID
path = f"tmp/data/{DEFAULT_GUID}/user/dialogue/{dialogue_id}.json"
with open(path,"r") as f:
    text = f.read()
print(text)
# Out:
# {
#     "last_message_order": 7,
#     "messages": [
#         {
#             "id": "fc46f385-05cf-4dd5-bd27-25ed18f627d1",
#             "header": {
#                 "sender": "User",
#                 "recipient": "Sara",
#                 "timestamp": 1752123060.2611365,
#                 "order": 0
#             },
#             "body": {
#                 "type": "send",
#                 "dialogue_id": "00000000-0000-0000-0000-000000000000",
#                 "message_no": 110,
#                 "message_id": "00000000-0000-0000-0000-000000000000.110",
#                 "content_type": "text",
#                 "content": "Tell me a one paragraph story"
#             }
#         },
#         {
#             "id": "8cc86f83-f6a8-4edb-92b4-4d7d0aa68802",
#             "header": {
#                 "sender": "User",
#                 "recipient": "Diana",
#                 "timestamp": 1752123060.2651765,
#                 "order": 0
#             },
#             "body": {
#                 "type": "send",
#                 "dialogue_id": "00000000-0000-0000-0000-000000000000",
#                 "message_no": 111,
#                 "message_id": "00000000-0000-0000-0000-000000000000.111",
#                 "content_type": "text",
#                 "content": "Please continue"
#             }
#         },
#         {
#             "id": "13d6cf90-a9ed-468d-9504-db7a676919a8",
#             "header": {
#                 "sender": "Sara",
#                 "recipient": "User",
#                 "timestamp": 1752123060.2793233,
#                 "order": 0
#             },
#             "body": {
#                 "type": "reply",
#                 "dialogue_id": "00000000-0000-0000-0000-000000000000",
#                 "message_no": 112,
#                 "message_id": "00000000-0000-0000-0000-000000000000.112",
#                 "chunk_no": 12,
#                 "chunk": "<eom>",
#                 "content_type": "text",
#                 "content": "This is a story about a brave knight who fought a dragon. "
#             }
#         },
#         {
#             "id": "05b5ffa4-93ad-4300-b3d9-420105d8ee73",
#             "header": {
#                 "sender": "Diana",
#                 "recipient": "User",
#                 "timestamp": 1752123060.2967486,
#                 "order": 0
#             },
#             "body": {
#                 "type": "reply",
#                 "dialogue_id": "00000000-0000-0000-0000-000000000000",
#                 "message_no": 113,
#                 "message_id": "00000000-0000-0000-0000-000000000000.113",
#                 "chunk_no": 8,
#                 "chunk": "<eom>",
#                 "content_type": "text",
#                 "content": "The knight was very brave and fought valiantly. "
#             }
#         },
#         {
#             "id": "4d9c8020-186c-43dc-9d14-938a31f5e7dd",
#             "header": {
#                 "sender": "User",
#                 "recipient": "*",
#                 "timestamp": 1752123063.2592404,
#                 "order": 0
#             },
#             "body": {
#                 "type": "send",
#                 "dialogue_id": "00000000-0000-0000-0000-000000000000",
#                 "message_no": 114,
#                 "message_id": "00000000-0000-0000-0000-000000000000.114",
#                 "content_type": "text",
#                 "content": "Introduce yourselves"
#             }
#         },
#         {
#             "id": "256045b1-ddf7-4614-bdbb-076f1362e274",
#             "header": {
#                 "sender": "Sara",
#                 "recipient": "User",
#                 "timestamp": 1752123063.271421,
#                 "order": 0
#             },
#             "body": {
#                 "type": "reply",
#                 "dialogue_id": "00000000-0000-0000-0000-000000000000",
#                 "message_no": 115,
#                 "message_id": "00000000-0000-0000-0000-000000000000.115",
#                 "chunk_no": 12,
#                 "chunk": "<eom>",
#                 "content_type": "text",
#                 "content": "This is a story about a brave knight who fought a dragon. "
#             }
#         },
#         {
#             "id": "7d56cc00-b37f-4d78-b124-58f0018f6543",
#             "header": {
#                 "sender": "Diana",
#                 "recipient": "User",
#                 "timestamp": 1752123063.27659,
#                 "order": 0
#             },
#             "body": {
#                 "type": "reply",
#                 "dialogue_id": "00000000-0000-0000-0000-000000000000",
#                 "message_no": 109,
#                 "message_id": "00000000-0000-0000-0000-000000000000.109",
#                 "chunk_no": 8,
#                 "chunk": "<eom>",
#                 "content_type": "text",
#                 "content": "The knight was very brave and fought valiantly. "
#             }
#         }
#     ]
# }
