# %% [markdown]
# ### a) Normal Monologue

# %%
from gai.asm.monologue import Monologue

# Create monologue
mono = Monologue(agent_name="TestBot", dialogue_id="test-123")

# Test initial state
assert mono.agent_name == "TestBot"
assert mono.dialogue_id == "test-123"
assert len(mono.list_messages()) == 0
print("✓ Initial state correct")

# Add user message
from types import SimpleNamespace
mock_input = {
    "step":1
}
mock_state = SimpleNamespace(state="GENERATE",input=mock_input,title="GENERATE")
mono.add_user_message("Hello, how are you?",mock_state)
messages = mono.list_messages()
assert len(messages) == 1
assert messages[0].body.role == "user"
assert messages[0].body.content == "Hello, how are you?"
print("✓ User message added correctly")

# Add assistant message
mock_input = {"step": 2}
mock_state = SimpleNamespace(state="GENERATE",input=mock_input,title="GENERATE")
mono.add_assistant_message("I'm doing well, thank you!",mock_state)
messages = mono.list_messages()
assert len(messages) == 2
assert messages[1].body.role == "assistant"
assert messages[1].body.content == "I'm doing well, thank you!"
print("✓ Assistant message added correctly")
# Out:
# ✓ Initial state correct
# ✓ User message added correctly
# ✓ Assistant message added correctly

# %% [markdown]
# ### b) File Monologue

# %%
from gai.asm.monologue import FileMonologue

# Create monologue
mono = FileMonologue(agent_name="TestBot", dialogue_id="test-123")
mono.reset()

# Test initial state
assert mono.agent_name == "TestBot"
assert mono.dialogue_id == "test-123"
assert len(mono.list_messages()) == 0
print("✓ Initial state correct")

# Add user message
from types import SimpleNamespace
mock_input = {"step": 1}
mock_state = SimpleNamespace(state="GENERATE", input=mock_input, title="GENERATE")
mono.add_user_message("Hello, how are you?", mock_state)
messages = mono.list_messages()
assert len(messages) == 1
assert messages[0].body.role == "user"
assert messages[0].body.content == "Hello, how are you?"
print("✓ User message added correctly")

# Add assistant message
mock_input = {"step": 2}
mock_state = SimpleNamespace(state="GENERATE", input=mock_input, title="GENERATE")
mono.add_assistant_message("I'm doing well, thank you!", mock_state)
messages = mono.list_messages()
assert len(messages) == 2
assert messages[1].body.role == "assistant"
assert messages[1].body.content == "I'm doing well, thank you!"
print("✓ Assistant message added correctly")

# Check saved
file_path=f"/tmp/TestBot.json"
with open(file_path,"r") as f:
    s=f.read()
    print(s)
# Out:
# ✓ Initial state correct
# ✓ User message added correctly
# ✓ Assistant message added correctly
# [
#     {
#         "id": "085234a7-8a30-46da-904d-76ab08955f63",
#         "header": {
#             "sender": "User",
#             "recipient": "TestBot",
#             "timestamp": 1752227787.080398,
#             "order": 0
#         },
#         "body": {
#             "type": "state",
#             "state_name": "GENERATE",
#             "step_no": 1,
#             "content_type": "text",
#             "role": "user",
#             "content": "Hello, how are you?"
#         }
#     },
#     {
#         "id": "c83f9236-16d7-4d8f-8911-5479b0d24504",
#         "header": {
#             "sender": "TestBot",
#             "recipient": "User",
#             "timestamp": 1752227787.0814939,
#             "order": 0
#         },
#         "body": {
#             "type": "state",
#             "state_name": "GENERATE",
#             "step_no": 2,
#             "content_type": "text",
#             "role": "assistant",
#             "content": "I'm doing well, thank you!"
#         }
#     }
# ]

# %%
from gai.asm.monologue import FileMonologue

# Create monologue
mono = FileMonologue(agent_name="TestBot", dialogue_id="test-123")

print(mono.list_messages())

print(mono.list_chat_messages())
# Out:
# [MessagePydantic(id='085234a7-8a30-46da-904d-76ab08955f63', header=MessageHeaderPydantic(sender='User', recipient='TestBot', timestamp=1752227787.080398, order=0), body=StateBodyPydantic(type='state', state_name='GENERATE', step_no=1, content_type='text', role='user', content='Hello, how are you?')), MessagePydantic(id='c83f9236-16d7-4d8f-8911-5479b0d24504', header=MessageHeaderPydantic(sender='TestBot', recipient='User', timestamp=1752227787.0814939, order=0), body=StateBodyPydantic(type='state', state_name='GENERATE', step_no=2, content_type='text', role='assistant', content="I'm doing well, thank you!"))]
# [{'role': 'user', 'content': 'Hello, how are you?'}, {'role': 'assistant', 'content': "I'm doing well, thank you!"}]
